# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # 2

# %%
message = pd.read_csv("message.csv")
message.plot(x='x', y='y', kind='scatter');

# %% [markdown]
# # 3

# %%
import json
with open("message.json") as f:
    message = json.load(f)

message = pd.DataFrame(message)

message = message.pivot(index='i', columns='j', values='value')

# replace nan with 0 and every other character with 1

message = message.fillna(' ')

# print every row of the message
for i in range(len(message)):
    print(' '.join(message.iloc[i]))
# Out:
#   _                 _                 _   _               _           _           _           _
# |   |             |   |             |   |   |           |   |       ( _ )       |   |       |   |
# |   | _   _ _ _   |   | _   _ _   _ |   |   | _       _ |   | _ _     _     _ _ |   |   _ _ |   |   _ _ _   _   _ _
# |   _ _ /   _   \ |   _ _ /   _ `   |   |   |   |   |   |   ' _   \ |   | /   _ `   | /   _ `   | /   _   \   ' _   \
# |   | |   ( _ )   |   | |   ( _ |   |   |   |   | _ |   |   |   |   |   |   ( _ |   |   ( _ |   |     _ _ /   |   |   |
#   \ _ _ \ _ _ _ /   \ _ _ \ _ _ , _ | _ | _ | \ _ _ ,   | _ |   | _ | _ | \ _ _ , _ | \ _ _ , _ | \ _ _ _ | _ |   | _ |
#                                                 _ _ /   |
#                                               | _ _ _ /

# %% [markdown]
# # 4

# %%
with open('words.txt', 'r') as file:
    words = file.read().splitlines()


pd.Series(words[0].split(',')).to_frame().assign(word_length=word_series.str.len()).sort_values('word_length', ascending=False).head(10)
# Out:
#                       0  word_length
# 8721  multidisciplinary           17
# 8644   enthusiastically           16
# 543    nondeterministic           16
# 8620    disintermediate           15
# 8667    functionalities           15
# 8722    multifunctional           15
# 905     geertruidenberg           15
# 8583    authoritatively           15
# 8765    reconceptualize           15
# 8687    infrastructures           15

# %% [markdown]
# # 5

# %%
ghost = plt.imread('ghost.png')

# %%
ghost
# Out:
# array([[[0.        , 0.6509804 , 0.36862746],
#         [0.        , 0.6784314 , 0.46666667],
#         [0.        , 0.25882354, 0.77254903],
#         ...,
#         [0.        , 0.14117648, 0.19607843],
#         [0.        , 0.17254902, 0.16078432],
#         [0.        , 0.64705884, 0.12156863]],
#
#        [[0.        , 0.16470589, 0.25882354],
#         [0.        , 0.9490196 , 0.92156863],
#         [0.        , 0.1882353 , 0.12941177],
#         ...,
#         [0.        , 0.30588236, 0.39607844],
#         [0.        , 0.54901963, 0.80784315],
#         [0.        , 0.7607843 , 0.6156863 ]],
#
#        [[0.        , 0.01176471, 0.40784314],
#         [0.        , 0.15294118, 0.23137255],
#         [0.        , 0.11372549, 0.8156863 ],
#         ...,
#         [0.        , 0.91764706, 0.08235294],
#         [0.        , 0.9019608 , 0.8509804 ],
#         [0.        , 0.2627451 , 0.09803922]],
#
#        ...,
#
#        [[0.        , 0.10196079, 0.4117647 ],
# ...
